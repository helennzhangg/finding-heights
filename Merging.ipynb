# %% [markdown]
# <a href="https://colab.research.google.com/github/helennzhangg/python-basics/blob/main/Merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Merging two data frames vertically, one on top of the other
roster1 = {"Name" : ["Bob", "Alice", "Joe", "Mike", "Lisa", "Alan", "Eli", "Mark", "Liz", "Jane"],
          "Major": ["Accounting", "Finance", "Chemistry", "Art", "Engineering", "Biology", "Physics", "History", "Art", "Engineering"],
          "GPA": [3.5, 3.8, 3.2, 3.7, 4.0, 3.5, 3.8, 3.2, 3.1, 3.0],
          "Age": [22, 23, 31, 40, 25, 22, 33, 31, 27, 55]          
          }

roster1_df = pd.DataFrame(roster1)

roster2 = {"Name" : ["Bob", "Alice", "Joe", "Mike", "Lisa", "Alan", "Eli", "Mark", "Liz", "Jane"],
          "Major": ["Accounting", "Finance", "Chemistry", "Art", "Engineering", "Biology", "Physics", "History", "Art", "Engineering"],
          "GPA": [3.5, 3.8, 3.2, 3.7, 4.0, 3.5, 3.8, 3.2, 3.1, 3.0],
          "Age": [22, 23, 31, 40, 25, 22, 33, 31, 27, 55]          
          }

roster2_df = pd.DataFrame(roster2)

# %%
roster2_df
# Out:
#     Name        Major  GPA  Age
# 0    Bob   Accounting  3.5   22
# 1  Alice      Finance  3.8   23
# 2    Joe    Chemistry  3.2   31
# 3   Mike          Art  3.7   40
# 4   Lisa  Engineering  4.0   25
# 5   Alan      Biology  3.5   22
# 6    Eli      Physics  3.8   33
# 7   Mark      History  3.2   31
# 8    Liz          Art  3.1   27
# 9   Jane  Engineering  3.0   55

# %%
roster3_df = pd.concat([roster1_df, roster2_df,roster1_df, roster2_df], axis=1)
roster3_df
# Out:
#     Name        Major  GPA  Age   Name        Major  GPA  Age   Name  \
# 0    Bob   Accounting  3.5   22    Bob   Accounting  3.5   22    Bob
# 1  Alice      Finance  3.8   23  Alice      Finance  3.8   23  Alice
# 2    Joe    Chemistry  3.2   31    Joe    Chemistry  3.2   31    Joe
# 3   Mike          Art  3.7   40   Mike          Art  3.7   40   Mike
# 4   Lisa  Engineering  4.0   25   Lisa  Engineering  4.0   25   Lisa
# 5   Alan      Biology  3.5   22   Alan      Biology  3.5   22   Alan
# 6    Eli      Physics  3.8   33    Eli      Physics  3.8   33    Eli
# 7   Mark      History  3.2   31   Mark      History  3.2   31   Mark
# 8    Liz          Art  3.1   27    Liz          Art  3.1   27    Liz
# 9   Jane  Engineering  3.0   55   Jane  Engineering  3.0   55   Jane
#
#          Major  GPA  Age   Name        Major  GPA  Age
# 0   Accounting  3.5   22    Bob   Accounting  3.5   22
# 1      Finance  3.8   23  Alice      Finance  3.8   23
# 2    Chemistry  3.2   31    Joe    Chemistry  3.2   31
# 3          Art  3.7   40   Mike          Art  3.7   40
# 4  Engineering  4.0   25   Lisa  Engineering  4.0   25
# 5      Biology  3.5   22   Alan      Biology  3.5   22
# 6      Physics  3.8   33    Eli      Physics  3.8   33
# 7      History  3.2   31   Mark      History  3.2   31
# 8          Art  3.1   27    Liz          Art  3.1   27
# 9  Engineering  3.0   55   Jane  Engineering  3.0   55

# %%
roster3_df = pd.concat([roster1_df, roster2_df], axis=1, ignore_index=True)
roster3_df
# Out:
#        0            1    2   3      4            5    6   7
# 0    Bob   Accounting  3.5  22    Bob   Accounting  3.5  22
# 1  Alice      Finance  3.8  23  Alice      Finance  3.8  23
# 2    Joe    Chemistry  3.2  31    Joe    Chemistry  3.2  31
# 3   Mike          Art  3.7  40   Mike          Art  3.7  40
# 4   Lisa  Engineering  4.0  25   Lisa  Engineering  4.0  25
# 5   Alan      Biology  3.5  22   Alan      Biology  3.5  22
# 6    Eli      Physics  3.8  33    Eli      Physics  3.8  33
# 7   Mark      History  3.2  31   Mark      History  3.2  31
# 8    Liz          Art  3.1  27    Liz          Art  3.1  27
# 9   Jane  Engineering  3.0  55   Jane  Engineering  3.0  55

# %%
#Merging two data frames vertically, one on top of the other
roster1 = {"emplid": [3421, 4723, 1331, 5435, 9453, 2345, 6234, 6845, 6245, 9645],
          "Name" : ["Bob", "Alice", "Joe", "Mike", "Lisa", "Alan", "Eli", "Mark", "Liz", "Jane"],
          "Major": ["Accounting", "Finance", "Chemistry", "Art", "Engineering", "Biology", "Physics", "History", "Art", "Engineering"],
          "GPA": [3.5, 3.8, 3.2, 3.7, 4.0, 3.5, 3.8, 3.2, 3.1, 3.0],
          "Age": [22, 23, 31, 40, 25, 22, 33, 31, 27, 55]          
          }

roster1_df = pd.DataFrame(roster1)

roster1_df
# Out:
#    emplid   Name        Major  GPA  Age
# 0    3421    Bob   Accounting  3.5   22
# 1    4723  Alice      Finance  3.8   23
# 2    1331    Joe    Chemistry  3.2   31
# 3    5435   Mike          Art  3.7   40
# 4    9453   Lisa  Engineering  4.0   25
# 5    2345   Alan      Biology  3.5   22
# 6    6234    Eli      Physics  3.8   33
# 7    6845   Mark      History  3.2   31
# 8    6245    Liz          Art  3.1   27
# 9    9645   Jane  Engineering  3.0   55

# %%
address = {"emplid": [3421, 1331, 5435, 2345, 6845, 7425, 4045, 8245],
          "Address" : ["1 Hyland Blvd", "88 Parkside Ave", "848 Jersey Turnpike", "3 Main Street", "231 Water Street", "22 1st Ave", "4 Grand Concourse", "222 William Street"],
          "City": ["Staten Island", "Brooklyn", "Hoboken", "Queens", "New Haven", "Manhattan", "Bronx", "Hempstead"],
          "State": ["NY", "NY", "NJ", "NY", "CT", "NY", "NY", "NY"],
          "Zipcode": [10304, 11220, 70086, 11432, 60511, 10024, 10458, 24231]          
          }

address_df = pd.DataFrame(address)

address_df
# Out:
#    emplid              Address           City State  Zipcode
# 0    3421        1 Hyland Blvd  Staten Island    NY    10304
# 1    1331      88 Parkside Ave       Brooklyn    NY    11220
# 2    5435  848 Jersey Turnpike        Hoboken    NJ    70086
# 3    2345        3 Main Street         Queens    NY    11432
# 4    6845     231 Water Street      New Haven    CT    60511
# 5    7425           22 1st Ave      Manhattan    NY    10024
# 6    4045    4 Grand Concourse          Bronx    NY    10458
# 7    8245   222 William Street      Hempstead    NY    24231

# %%
result = pd.merge(roster1_df, address_df, how='left', on= ['emplid'] )
result
# Out:
#    emplid   Name        Major  GPA  Age              Address           City  \
# 0    3421    Bob   Accounting  3.5   22        1 Hyland Blvd  Staten Island
# 1    4723  Alice      Finance  3.8   23                  NaN            NaN
# 2    1331    Joe    Chemistry  3.2   31      88 Parkside Ave       Brooklyn
# 3    5435   Mike          Art  3.7   40  848 Jersey Turnpike        Hoboken
# 4    9453   Lisa  Engineering  4.0   25                  NaN            NaN
# 5    2345   Alan      Biology  3.5   22        3 Main Street         Queens
# 6    6234    Eli      Physics  3.8   33                  NaN            NaN
# 7    6845   Mark      History  3.2   31     231 Water Street      New Haven
# 8    6245    Liz          Art  3.1   27                  NaN            NaN
# 9    9645   Jane  Engineering  3.0   55                  NaN            NaN
#
#   State  Zipcode
# 0    NY  10304.0
# 1   NaN      NaN
# 2    NY  11220.0
# 3    NJ  70086.0
# 4   NaN      NaN
# 5    NY  11432.0
# 6   NaN      NaN
# 7    CT  60511.0
# 8   NaN      NaN
# 9   NaN      NaN

# %%
#Merging two data frames vertically, one on top of the other
athletics = {"emplid": [3333,4723, 1331, 1111, 5435,  2345, 2222, 6234, 6245, 9645,4444],
          "Sport" : ["Basketball", "Baseball", "Soccer", "Basketball", "Swimming", "Soccer", "Volleyball","Chess","Soccer","Tennis","Basketball"],
          "Medals": [1, 0, 2, 0, 3, 5, 0,4,5,0,1],
          "Stipend": ["yes", "no", "no", "yes", "yes", "no","yes","yes","yes","no","no"],
          "Practice Hours": [220, 123, 331, 140, 125, 252, 3, 24,51,20,55]          
          }

athletics_df = pd.DataFrame(athletics)

athletics_df
# Out:
#     emplid       Sport  Medals Stipend  Practice Hours
# 0     3333  Basketball       1     yes             220
# 1     4723    Baseball       0      no             123
# 2     1331      Soccer       2      no             331
# 3     1111  Basketball       0     yes             140
# 4     5435    Swimming       3     yes             125
# 5     2345      Soccer       5      no             252
# 6     2222  Volleyball       0     yes               3
# 7     6234       Chess       4     yes              24
# 8     6245      Soccer       5     yes              51
# 9     9645      Tennis       0      no              20
# 10    4444  Basketball       1      no              55

# %%
result = pd.merge(roster1_df, athletics_df, how='right', on= ['emplid'] )
result
# Out:
#     emplid   Name        Major  GPA   Age       Sport  Medals Stipend  \
# 0     3333    NaN          NaN  NaN   NaN  Basketball       1     yes
# 1     4723  Alice      Finance  3.8  23.0    Baseball       0      no
# 2     1331    Joe    Chemistry  3.2  31.0      Soccer       2      no
# 3     1111    NaN          NaN  NaN   NaN  Basketball       0     yes
# 4     5435   Mike          Art  3.7  40.0    Swimming       3     yes
# 5     2345   Alan      Biology  3.5  22.0      Soccer       5      no
# 6     2222    NaN          NaN  NaN   NaN  Volleyball       0     yes
# 7     6234    Eli      Physics  3.8  33.0       Chess       4     yes
# 8     6245    Liz          Art  3.1  27.0      Soccer       5     yes
# 9     9645   Jane  Engineering  3.0  55.0      Tennis       0      no
# 10    4444    NaN          NaN  NaN   NaN  Basketball       1      no
#
#     Practice Hours
# 0              220
# 1              123
# 2              331
# 3              140
# 4              125
# 5              252
# 6                3
# 7               24
# 8               51
# 9               20
# 10              55

# %%
result = pd.merge(roster1_df, athletics_df, how='inner', on= ['emplid'] )
result
# Out:
#    emplid   Name        Major  GPA  Age     Sport  Medals Stipend  \
# 0    4723  Alice      Finance  3.8   23  Baseball       0      no
# 1    1331    Joe    Chemistry  3.2   31    Soccer       2      no
# 2    5435   Mike          Art  3.7   40  Swimming       3     yes
# 3    2345   Alan      Biology  3.5   22    Soccer       5      no
# 4    6234    Eli      Physics  3.8   33     Chess       4     yes
# 5    6245    Liz          Art  3.1   27    Soccer       5     yes
# 6    9645   Jane  Engineering  3.0   55    Tennis       0      no
#
#    Practice Hours
# 0             123
# 1             331
# 2             125
# 3             252
# 4              24
# 5              51
# 6              20

# %%
result = pd.merge(roster1_df, address_df, how='outer', on= ['emplid'] )
result
# Out:
#     emplid   Name        Major  GPA   Age              Address           City  \
# 0     3421    Bob   Accounting  3.5  22.0        1 Hyland Blvd  Staten Island
# 1     4723  Alice      Finance  3.8  23.0                  NaN            NaN
# 2     1331    Joe    Chemistry  3.2  31.0      88 Parkside Ave       Brooklyn
# 3     5435   Mike          Art  3.7  40.0  848 Jersey Turnpike        Hoboken
# 4     9453   Lisa  Engineering  4.0  25.0                  NaN            NaN
# 5     2345   Alan      Biology  3.5  22.0        3 Main Street         Queens
# 6     6234    Eli      Physics  3.8  33.0                  NaN            NaN
# 7     6845   Mark      History  3.2  31.0     231 Water Street      New Haven
# 8     6245    Liz          Art  3.1  27.0                  NaN            NaN
# 9     9645   Jane  Engineering  3.0  55.0                  NaN            NaN
# 10    7425    NaN          NaN  NaN   NaN           22 1st Ave      Manhattan
# 11    4045    NaN          NaN  NaN   NaN    4 Grand Concourse          Bronx
# 12    8245    NaN          NaN  NaN   NaN   222 William Street      Hempstead
#
#    State  Zipcode
# 0     NY  10304.0
# 1    NaN      NaN
# 2     NY  11220.0
# 3     NJ  70086.0
# 4    NaN      NaN
# 5     NY  11432.0
# 6    NaN      NaN
# 7     CT  60511.0
# 8    NaN      NaN
# 9    NaN      NaN
# 10    NY  10024.0
# 11    NY  10458.0
# 12    NY  24231.0

# %%
mean_values = result[ ['Age','GPA'] ].mean()
print(mean_values)
# Out:
# Age    30.90
# GPA     3.48
# dtype: float64

# %%
result[['Age','GPA']] = result[['Age','GPA']].fillna(value=mean_values)

# %%
result
# Out:
#     emplid   Name        Major   GPA   Age              Address  \
# 0     3421    Bob   Accounting  3.50  22.0        1 Hyland Blvd
# 1     4723  Alice      Finance  3.80  23.0                  NaN
# 2     1331    Joe    Chemistry  3.20  31.0      88 Parkside Ave
# 3     5435   Mike          Art  3.70  40.0  848 Jersey Turnpike
# 4     9453   Lisa  Engineering  4.00  25.0                  NaN
# 5     2345   Alan      Biology  3.50  22.0        3 Main Street
# 6     6234    Eli      Physics  3.80  33.0                  NaN
# 7     6845   Mark      History  3.20  31.0     231 Water Street
# 8     6245    Liz          Art  3.10  27.0                  NaN
# 9     9645   Jane  Engineering  3.00  55.0                  NaN
# 10    7425    NaN          NaN  3.48  30.9           22 1st Ave
# 11    4045    NaN          NaN  3.48  30.9    4 Grand Concourse
# 12    8245    NaN          NaN  3.48  30.9   222 William Street
#
#              City State  Zipcode
# 0   Staten Island    NY  10304.0
# 1             NaN   NaN      NaN
# 2        Brooklyn    NY  11220.0
# 3         Hoboken    NJ  70086.0
# 4             NaN   NaN      NaN
# 5          Queens    NY  11432.0
# 6             NaN   NaN      NaN
# 7       New Haven    CT  60511.0
# 8             NaN   NaN      NaN
# 9             NaN   NaN      NaN
# 10      Manhattan    NY  10024.0
# 11          Bronx    NY  10458.0
# 12      Hempstead    NY  24231.0

# %%
result.dropna(inplace=True)

# %%
result
# Out:
#    emplid  Name       Major  GPA   Age              Address           City  \
# 0    3421   Bob  Accounting  3.5  22.0        1 Hyland Blvd  Staten Island
# 2    1331   Joe   Chemistry  3.2  31.0      88 Parkside Ave       Brooklyn
# 3    5435  Mike         Art  3.7  40.0  848 Jersey Turnpike        Hoboken
# 5    2345  Alan     Biology  3.5  22.0        3 Main Street         Queens
# 7    6845  Mark     History  3.2  31.0     231 Water Street      New Haven
#
#   State  Zipcode
# 0    NY  10304.0
# 2    NY  11220.0
# 3    NJ  70086.0
# 5    NY  11432.0
# 7    CT  60511.0

# %%
X = pd.merge(roster1_df, address_df, how="inner", on = ["emplid"])
X
# Out:
#    emplid  Name       Major  GPA  Age              Address           City  \
# 0    3421   Bob  Accounting  3.5   22        1 Hyland Blvd  Staten Island
# 1    1331   Joe   Chemistry  3.2   31      88 Parkside Ave       Brooklyn
# 2    5435  Mike         Art  3.7   40  848 Jersey Turnpike        Hoboken
# 3    2345  Alan     Biology  3.5   22        3 Main Street         Queens
# 4    6845  Mark     History  3.2   31     231 Water Street      New Haven
#
#   State  Zipcode
# 0    NY    10304
# 1    NY    11220
# 2    NJ    70086
# 3    NY    11432
# 4    CT    60511

# %%
Y = pd.merge(X, athletics_df, how="inner", on =["emplid"])
Y
# Out:
#    emplid  Name      Major  GPA  Age              Address      City State  \
# 0    1331   Joe  Chemistry  3.2   31      88 Parkside Ave  Brooklyn    NY
# 1    5435  Mike        Art  3.7   40  848 Jersey Turnpike   Hoboken    NJ
# 2    2345  Alan    Biology  3.5   22        3 Main Street    Queens    NY
#
#    Zipcode     Sport  Medals Stipend  Practice Hours
# 0    11220    Soccer       2      no             331
# 1    70086  Swimming       3     yes             125
# 2    11432    Soccer       5      no             252

# %%
Y[['GPA','Age', 'Medals','Practice Hours']].describe()
# Out:
#             GPA   Age    Medals  Practice Hours
# count  3.000000   3.0  3.000000         3.00000
# mean   3.466667  31.0  3.333333       236.00000
# std    0.251661   9.0  1.527525       103.92786
# min    3.200000  22.0  2.000000       125.00000
# 25%    3.350000  26.5  2.500000       188.50000
# 50%    3.500000  31.0  3.000000       252.00000
# 75%    3.600000  35.5  4.000000       291.50000
# max    3.700000  40.0  5.000000       331.00000

# %%
result = pd.merge(roster1_df, address_df, how='outer', on= ['emplid'] )
result.dropna(inplace = True)

# %%
result
# Out:
#    emplid  Name       Major  GPA   Age              Address           City  \
# 0    3421   Bob  Accounting  3.5  22.0        1 Hyland Blvd  Staten Island
# 2    1331   Joe   Chemistry  3.2  31.0      88 Parkside Ave       Brooklyn
# 3    5435  Mike         Art  3.7  40.0  848 Jersey Turnpike        Hoboken
# 5    2345  Alan     Biology  3.5  22.0        3 Main Street         Queens
# 7    6845  Mark     History  3.2  31.0     231 Water Street      New Haven
#
#   State  Zipcode
# 0    NY  10304.0
# 2    NY  11220.0
# 3    NJ  70086.0
# 5    NY  11432.0
# 7    CT  60511.0

# %%
result3 = pd.merge(roster1_df, address_df, how='outer', on= ['emplid'] )
result3
# Out:
#     emplid   Name        Major  GPA   Age              Address           City  \
# 0     3421    Bob   Accounting  3.5  22.0        1 Hyland Blvd  Staten Island
# 1     4723  Alice      Finance  3.8  23.0                  NaN            NaN
# 2     1331    Joe    Chemistry  3.2  31.0      88 Parkside Ave       Brooklyn
# 3     5435   Mike          Art  3.7  40.0  848 Jersey Turnpike        Hoboken
# 4     9453   Lisa  Engineering  4.0  25.0                  NaN            NaN
# 5     2345   Alan      Biology  3.5  22.0        3 Main Street         Queens
# 6     6234    Eli      Physics  3.8  33.0                  NaN            NaN
# 7     6845   Mark      History  3.2  31.0     231 Water Street      New Haven
# 8     6245    Liz          Art  3.1  27.0                  NaN            NaN
# 9     9645   Jane  Engineering  3.0  55.0                  NaN            NaN
# 10    7425    NaN          NaN  NaN   NaN           22 1st Ave      Manhattan
# 11    4045    NaN          NaN  NaN   NaN    4 Grand Concourse          Bronx
# 12    8245    NaN          NaN  NaN   NaN   222 William Street      Hempstead
#
#    State  Zipcode
# 0     NY  10304.0
# 1    NaN      NaN
# 2     NY  11220.0
# 3     NJ  70086.0
# 4    NaN      NaN
# 5     NY  11432.0
# 6    NaN      NaN
# 7     CT  60511.0
# 8    NaN      NaN
# 9    NaN      NaN
# 10    NY  10024.0
# 11    NY  10458.0
# 12    NY  24231.0

# %%
meanvalues = result3[['Age', 'GPA']].mean()

# %%
result3[['Age', 'GPA']] = result3[['Age', 'GPA']].fillna(value=meanvalues)

# %%
result3
# Out:
#     emplid   Name        Major   GPA   Age              Address  \
# 0     3421    Bob   Accounting  3.50  22.0        1 Hyland Blvd
# 1     4723  Alice      Finance  3.80  23.0                  NaN
# 2     1331    Joe    Chemistry  3.20  31.0      88 Parkside Ave
# 3     5435   Mike          Art  3.70  40.0  848 Jersey Turnpike
# 4     9453   Lisa  Engineering  4.00  25.0                  NaN
# 5     2345   Alan      Biology  3.50  22.0        3 Main Street
# 6     6234    Eli      Physics  3.80  33.0                  NaN
# 7     6845   Mark      History  3.20  31.0     231 Water Street
# 8     6245    Liz          Art  3.10  27.0                  NaN
# 9     9645   Jane  Engineering  3.00  55.0                  NaN
# 10    7425    NaN          NaN  3.48  30.9           22 1st Ave
# 11    4045    NaN          NaN  3.48  30.9    4 Grand Concourse
# 12    8245    NaN          NaN  3.48  30.9   222 William Street
#
#              City State  Zipcode
# 0   Staten Island    NY  10304.0
# 1             NaN   NaN      NaN
# 2        Brooklyn    NY  11220.0
# 3         Hoboken    NJ  70086.0
# 4             NaN   NaN      NaN
# 5          Queens    NY  11432.0
# 6             NaN   NaN      NaN
# 7       New Haven    CT  60511.0
# 8             NaN   NaN      NaN
# 9             NaN   NaN      NaN
# 10      Manhattan    NY  10024.0
# 11          Bronx    NY  10458.0
# 12      Hempstead    NY  24231.0
